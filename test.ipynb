# %% [markdown]
# # Data acquisition and processing demo
#
# This notebook demonstrates the current capabilities of the **Funding Rates Arbitrage** project, a system for real-time cryptocurrency data acquisition, processing, analysis and trading.
#
# Key Features Demonstrated:
# - **Multi-exchange data collection with CCXT** (Binance, Hyperliquid)
# - **Real-time time series management** with shared memory
# - **Built series with dependencies** (technical indicators or strategies)
# - **Database persistence** with DuckDB
# - **MPI-based** shared memory
#
# The project aims to enable sophisticated trading strategies by providing efficient data structures, real-time processing, and multi-process coordination.

# %% [markdown]
# ## Imports and Initialization
#
# First, we import the core components of the package:

# %%
from core.data.models.time_series import *
from core.data.streaming.DataRegistry import *
# Out:
# [MacBook-Air-4.local:65583] shmem: mmap: an error occurred while determining whether or not /var/folders/4b/k1tn9tg90lq4g9v84ws8c_xw0000gn/T//ompi.MacBook-Air-4.501/jf.0/2042822656/sm_segment.MacBook-Air-4.501.79c30000.0 could be created.

# %% [markdown]
# (1) MPI Setup for Multi-Process Communication
#
# The package uses **MPI4Py** for efficient multi-process communication and shared memory management:

# %%
from mpi4py import MPI
comm = MPI.COMM_WORLD
rank = comm.Get_rank()

# %% [markdown]
# (2) DataRegistry - Central Time Series Management
#
# The **DataRegistry** is the core component that manages all time series data with:
# - UUID-based indexing
# - Metadata-based lookup
# - Dependency management
# - Database integration

# %%
registry = DataRegistry(comm, rank)

# %% [markdown]
# ## Creating Time Series acquired from crypto exchanges
#
# We create multiple time series from different exchanges with various data types and timeframes:
#
# - **Binance BTC/USDT OHLCV** (1-minute intervals)
# - **Binance BTC/USDT:USDT Funding Rate** (8-hour intervals)
# - **Binance BTC/USDT:USDT OHLCV** (1-minute intervals)
# - **Binance BTC/USDT:USDT current Funding Rate** (10-second intervals)
# - **Hyperliquid BTC/USDC:USDC Funding Rate** (1-hour intervals)
#
# Each series uses a cache size of 4 for efficient memory management.

# %%
registry.create_third_party_series("binance","BTC/USDT","OHLCV",60000, cache=4)
registry.create_third_party_series("binance","BTC/USDT:USDT","fundingRate",60000 * 60 * 8, cache=4)
registry.create_third_party_series("binance","BTC/USDT:USDT","OHLCV",60000, cache=4)
registry.create_third_party_series("binance","BTC/USDT:USDT","tmpfundingRate",10000, cache=4)
registry.create_third_party_series("hyperliquid","BTC/USDC:USDC","fundingRate",60000 * 60, cache=4)
# Out:
# '81025db5-48a2-46f8-a5e3-5aba2296a6e0'

# %% [markdown]
# # Subscription Management
#
# The project includes a functionality to save and load CCXT subscriptions for persistence:

# %%
registry.save_ccxt_subscriptions( "sub.json")

# %% [markdown]
# We can recreate the registry and load previously saved subscriptions. This demonstrates:
# - **Configuration persistence**
# - **Registry reconstruction**
# - **Automatic series creation** from metadata

# %%
registry = DataRegistry(comm, rank)
registry.load_series_metadata("sub.json")
registry.create_third_party_from_file("sub.json")
# Out:
# ['face875f-94c5-4e05-a9e1-bd9b96b1cd4f',
#  'd921b275-3cd3-48a9-adbf-fd6eee835928',
#  '733af7e7-4be4-4ab2-b28e-404908e6db43',
#  '9f0ba70f-5225-4dbd-aaa2-824b20c75c0c',
#  '26eb92b1-9729-4e05-8b40-2670deb3341f']

# %% [markdown]
# ## Retrieving Time Series Objects
#
# Once created in the DataRegistry, time series can be retrieved using their metadata tuple (exchange, symbol, data_type, timeframe):

# %%
ohlcv = registry.get_series( ("binance","BTC/USDT","OHLCV",60000) )
fundingRate = registry.get_series( ("hyperliquid","BTC/USDC:USDC","fundingRate",60000 * 60) )
fundingRatebis = registry.get_series( ("binance","BTC/USDT:USDT","fundingRate",60000 * 60 * 8) )
ohlcv_bis = registry.get_series( ("binance","BTC/USDT:USDT","OHLCV",60000) )
tmpfundingRatebis = registry.get_series( ("binance","BTC/USDT:USDT","tmpfundingRate",10000) )

# %% [markdown]
# ## Built Series with Dependencies
#
# The project includes code to create **built series** that depend on other time series. This enables:
#
# - **Real-time technical analysis**
# - **Multi-series calculations**
# - **Dependency-based updates**
# - **Integration with TA-Lib**
#
# Here we create some built series for the purpose of illustration.

# %%
def ma_transition(deps, prev_data):
    ohlcv = deps[0]
    return np.mean(ohlcv.data[-2:], axis=0)

ma_id = registry.create_built_series(
    duration = 60000,
    transition_function=ma_transition,
    dependencies=[("binance", "BTC/USDT", "OHLCV",60000)],  # Reference by metadata
    data_shape=5,  # Output shape
    cache = 2,
    symbol = "MA2BTC/USDT",
    serie_type = "OHLCV"
)
ma_serie = registry.get_series(ma_id)

# %%
from core.data.processing.transforms import ta_lib

ma_transition_talib = lambda x,y : ta_lib(x,y,"sma",timeperiod=2)

ma_talib_id = registry.create_built_series(
    duration = 60000,
    transition_function = ma_transition_talib,
    dependencies= [("binance", "BTC/USDT", "OHLCV",60000)],  # Reference by metadata
    data_shape = 5,  # Output shape
    cache = 4,
    symbol = "smothed_BTC/USDT",
    serie_type = "OHLCV"
)
ma_talib_serie = registry.get_series(ma_talib_id)

# %%
def max_transition(deps, prev_data):
    tmp = np.array( [ serie_data[-1] for serie_data in deps ] )
    return np.argmax(tmp, axis=0)

max_id = registry.create_built_series(
    duration = 60000,
    transition_function = max_transition,
    dependencies=[  ("binance", "BTC/USDT", "OHLCV",60000),
                    ('local', 'MA2BTC/USDT', 'OHLCV', 60000)],  # Reference by metadata
    data_shape=5,  # Output shape
    cache = 2,
    symbol = "MAX2BTC/USDT",
    serie_type = "max"
)
max_serie = registry.get_series(max_id)

# %%
from core.data.processing.transforms import ohlcv_from_ohlcv

one_min_to_three_min = lambda x,y : ohlcv_from_ohlcv(x, y, 60000, 3*60000)

three_min_btc_id = registry.create_built_series(
    duration = 3 * 60000,
    transition_function = one_min_to_three_min,
    dependencies=[  ("binance", "BTC/USDT", "OHLCV",60000)],  # Reference by metadata
    data_shape=5,  # Output shape
    cache = 2,
    symbol = "BTC/USDT",
    serie_type = "OHLCV"
)
three_min_btc = registry.get_series(three_min_btc_id)

# %% [markdown]
# The registry maintains a metadata index that maps series metadata to their UUIDs.
#
# Below we check that the the metadata index contains every serie we created:

# %%
registry._metadata_index
# Out:
# {('binance',
#   'BTC/USDT',
#   'OHLCV',
#   60000): 'face875f-94c5-4e05-a9e1-bd9b96b1cd4f',
#  ('binance',
#   'BTC/USDT:USDT',
#   'fundingRate',
#   28800000): 'd921b275-3cd3-48a9-adbf-fd6eee835928',
#  ('binance',
#   'BTC/USDT:USDT',
#   'OHLCV',
#   60000): '733af7e7-4be4-4ab2-b28e-404908e6db43',
#  ('binance',
#   'BTC/USDT:USDT',
#   'tmpfundingRate',
#   10000): '9f0ba70f-5225-4dbd-aaa2-824b20c75c0c',
#  ('hyperliquid',
#   'BTC/USDC:USDC',
#   'fundingRate',
#   3600000): '26eb92b1-9729-4e05-8b40-2670deb3341f',
#  ('local',
#   'MA2BTC/USDT',
#   'OHLCV',
#   60000): '068f560b-c3c2-4e7d-a593-a951876726c2',
#  ('local',
#   'smothed_BTC/USDT',
#   'OHLCV',
#   60000): '244c5485-9488-4aac-9698-308bf9c9044e',
#  ('local',
#   'MAX2BTC/USDT',
#   'max',
#   60000): '36fcb84d-a2fa-473b-9d90-c4bc8acdbe8b',
#  ('local',
#   'BTC/USDT',
#   'OHLCV',
#   180000): 'c0029a8b-2f61-453e-8d8a-8d69f1ecf36d'}

# %% [markdown]
# ## Database Integration with DuckDB
#
# The package provides seamless **DuckDB integration** for data persistence and retrieval:
#
# - **Automatic data loading** from existing database
# - **Historical data persistence**
# - **Efficient columnar storage**
# - **SQL-compatible queries**
#
# We load the data from the database if it exists.

# %%
import duckdb
conn = duckdb.connect('test.db')
loaded, fail_to_load = registry.load_all_from_db(conn)
# Out:
# Series not found in database:
# - binance BTC/USDT OHLCV 60000
# - binance BTC/USDT:USDT fundingRate 28800000
# - binance BTC/USDT:USDT OHLCV 60000
# - binance BTC/USDT:USDT tmpfundingRate 10000
# - hyperliquid BTC/USDC:USDC fundingRate 3600000
# - local MA2BTC/USDT OHLCV 60000
# - local smothed_BTC/USDT OHLCV 60000
# - local MAX2BTC/USDT max 60000
# - local BTC/USDT OHLCV 180000

# %% [markdown]
# ## Data acquisition from crypto exchanges
#
# We use the CCXT package and its API to acquire the data from the crypto exchanges. It relies on asyncio to use concurrent programming.

# %%
ccxt_feeder = registry.subscribe_to_ccxt_adapter(start_time= int( time.time() * 1000 / (8*60000*60) ) * (8*60000*60) - 60 * 60000, conn = conn)

# %% [markdown]
# We start the data acquisition.

# %%
ccxt_feeder.run()
# Out:
# Start collecting :  Binance BTC/USDT OHLCV 1m
# Start collecting :  Binance BTC/USDT:USDT OHLCV 1m
# Start collecting :  Binance BTC/USDT:USDT fundingRate 8h
# Start collecting :  Binance BTC/USDT:USDT tmpfundingRate 10s
# Start collecting :  Hyperliquid BTC/USDC:USDC fundingRate 1h
# ______________________________________________________________________
# 2025-09-08 02:00:00 : successful acquisition of duration  28800000
# ______________________________________________________________________
# 2025-09-08 12:18:50 : successful acquisition of duration  10000
# ______________________________________________________________________
# 2025-09-08 09:00:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 10:00:00 : successful acquisition of duration  28800000
# ______________________________________________________________________
# 2025-09-08 09:01:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:02:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:03:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:00:00 : successful acquisition of duration  3600000
# ______________________________________________________________________
# 2025-09-08 09:04:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:05:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 10:00:00 : successful acquisition of duration  3600000
# ______________________________________________________________________
# 2025-09-08 09:06:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:07:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 11:00:00 : successful acquisition of duration  3600000
# ______________________________________________________________________
# 2025-09-08 09:08:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 12:19:00 : successful acquisition of duration  10000
# ______________________________________________________________________
# 2025-09-08 09:09:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 12:00:00 : successful acquisition of duration  3600000
# ______________________________________________________________________
# 2025-09-08 09:10:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:11:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:12:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:13:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:14:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:15:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:16:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:17:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:18:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 12:19:10 : successful acquisition of duration  10000
# ______________________________________________________________________
# 2025-09-08 09:19:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:20:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:21:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:22:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:23:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:24:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:25:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:26:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:27:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:28:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:29:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:30:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:31:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:32:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 12:19:20 : successful acquisition of duration  10000
# ______________________________________________________________________
# 2025-09-08 09:33:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:34:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:35:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:36:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:37:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:38:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:39:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:40:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:41:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:42:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:43:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:44:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:45:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 12:19:30 : successful acquisition of duration  10000
# ______________________________________________________________________
# 2025-09-08 09:46:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:47:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:48:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:49:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:50:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:51:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:52:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:53:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:54:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:55:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:56:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 12:19:40 : successful acquisition of duration  10000
# ______________________________________________________________________
# 2025-09-08 09:57:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:58:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 09:59:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 10:00:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 10:01:00 : successful acquisition of duration  60000
# ______________________________________________________________________
# 2025-09-08 10:02:00 : successful acquisition of duration  60000

# %% [markdown]
# ## Built series computation
#
# In below code we use rely on asyncio routines and the threading module from python to concurently compute the built series, taking dependancies into account, when acquired data is available.
#
# In practice it will be done, using MPI4py, in a process distinct from the one in charge of data acquisition from the exchanges.

# %%
import asyncio
import threading
import time

async def updata_built_series(registry):
    while True:
        time.sleep(0.5)
        registry.series_manager.update_all()


coroutine = updata_built_series(registry)
#asyncio.run(coroutine)

runner_thread = threading.Thread(target= (lambda : asyncio.run(coroutine)), daemon=False)

runner_thread.start()
# Out:
# ______________________________________________________________________
# 2025-09-08 09:00:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:00:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:00:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:00:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:01:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:01:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:01:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:02:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:02:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:02:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:03:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:03:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:03:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:03:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:04:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:04:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:04:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:05:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:05:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:05:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:06:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:06:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:06:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:06:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:07:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:07:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:07:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:08:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:08:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:08:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:09:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:09:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:09:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:09:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:10:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:10:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:10:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:11:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:11:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:11:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:12:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:12:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:12:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:12:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:13:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:13:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:13:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:14:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:14:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:14:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:15:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:15:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:15:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:15:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:16:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:16:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:16:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:17:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:17:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:17:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:18:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:18:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:18:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:18:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:19:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:19:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:19:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:20:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:20:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:20:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:21:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:21:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:21:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:21:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:22:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:22:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:22:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:23:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:23:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:23:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:24:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:24:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:24:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:24:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:25:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:25:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:25:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:26:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:26:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:26:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:27:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:27:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:27:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:27:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:28:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:28:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:28:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:29:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:29:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:29:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:30:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:30:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:30:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:30:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:31:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:31:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:31:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:32:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:32:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:32:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:33:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:33:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:33:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:33:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:34:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:34:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:34:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:35:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:35:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:35:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:36:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:36:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:36:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:36:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:37:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:37:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:37:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:38:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:38:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:38:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:39:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:39:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:39:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:39:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:40:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:40:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:40:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:41:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:41:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:41:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:42:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:42:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:42:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:42:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:43:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:43:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:43:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:44:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:44:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:44:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:45:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:45:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:45:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:45:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:46:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:46:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:46:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:47:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:47:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:47:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:48:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:48:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:48:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:48:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:49:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:49:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:49:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:50:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:50:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:50:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:51:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:51:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:51:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:51:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:52:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:52:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:52:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:53:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:53:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:53:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:54:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:54:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:54:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:54:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:55:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:55:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:55:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:56:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:56:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:56:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:57:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:57:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 09:57:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:57:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:58:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:58:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:58:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 09:59:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:59:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 09:59:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 10:00:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 10:00:00 : successful computation of   local BTC/USDT OHLCV 180000
# ______________________________________________________________________
# 2025-09-08 10:00:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 10:00:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 10:01:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 10:01:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 10:01:00 : successful computation of   local MAX2BTC/USDT max 60000
# ______________________________________________________________________
# 2025-09-08 10:02:00 : successful computation of   local MA2BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 10:02:00 : successful computation of   local smothed_BTC/USDT OHLCV 60000
# ______________________________________________________________________
# 2025-09-08 10:02:00 : successful computation of   local MAX2BTC/USDT max 60000

# %% [markdown]
# ## Outcome
#
# We check that everything is working by looking at the timestamps (the value $-1$ means no data).
#
# Note that *max_serie* depends on both *ma_serie* and *ohlcv* and *ma_serie* depends on *ohlcv*.

# %%
# wait for some data to be acquired
time.sleep(10)

ohlcv.timestamps, ma_serie.timestamps, max_serie.timestamps
# Out:
# (array([[1.75731528e+12],
#         [1.75731534e+12],
#         [1.75731540e+12],
#         [1.75731546e+12]]),
#  array([[1.75731534e+12],
#         [1.75731540e+12]]),
#  array([[1.75731534e+12],
#         [1.75731540e+12]]))

# %% [markdown]
# We look at the last values of each time series considered above.

# %%
ohlcv.data[-2:], ma_serie.data[-2:], max_serie.data[-1]
# Out:
# (array([[1.1118952e+05, 1.1119613e+05, 1.1117614e+05, 1.1119613e+05,
#          1.6825700e+00],
#         [1.1119612e+05, 1.1121528e+05, 1.1119612e+05, 1.1121527e+05,
#          2.0478100e+00]]),
#  array([[1.11235995e+05, 1.11236000e+05, 1.11198500e+05, 1.11205765e+05,
#          7.47965000e+00],
#         [1.11205760e+05, 1.11209065e+05, 1.11182830e+05, 1.11192830e+05,
#          3.64426500e+00]]),
#  array([1., 1., 1., 0., 1.]))

# %% [markdown]
# We also check the timestamps for the 3m OHLCV built from the 1m OHLCV series.

# %%
ohlcv.timestamps, three_min_btc.timestamps
# Out:
# (array([[1.75731528e+12],
#         [1.75731534e+12],
#         [1.75731540e+12],
#         [1.75731546e+12]]),
#  array([[1.75731516e+12],
#         [1.75731534e+12]]))

# %% [markdown]
# We load the whole data stored in the database for the 1m OHLCV BTC/USDT from Binance.

# %%
table_name = generate_table_name("binance","BTC/USDT","OHLCV",60000)
#table_name = generate_table_name("binance","BTC/USDT:USDT","fundingRate",60000*8*60)
query = f"SELECT * FROM {table_name}"
query += " ORDER BY timestamp"
df = conn.execute(query).fetchdf()
df
# Out:
#         timestamp         data_0         data_1         data_2         data_3  \
# 0              -1            NaN            NaN            NaN            NaN
# 1   1757314800000  111113.257812  111149.960938  111113.250000  111148.906250
# 2   1757314860000  111148.898438  111200.000000  111148.898438  111184.742188
# 3   1757314920000  111184.742188  111184.742188  111175.812500  111175.812500
# 4   1757314980000  111175.820312  111184.992188  111157.593750  111184.976562
# 5   1757315040000  111184.992188  111217.312500  111171.992188  111217.312500
# 6   1757315100000  111217.312500  111229.726562  111217.296875  111229.726562
# 7   1757315160000  111229.718750  111231.906250  111216.039062  111231.906250
# 8   1757315220000  111231.921875  111250.000000  111231.921875  111250.000000
# 9   1757315280000  111249.992188  111250.000000  111207.476562  111222.000000
# 10  1757315340000  111222.000000  111222.000000  111189.523438  111189.531250
# 11  1757315400000  111189.523438  111196.132812  111176.140625  111196.132812
# 12  1757315460000  111196.117188  111215.281250  111196.117188  111215.273438
#
#       data_4
# 0        NaN
# 1    1.82780
# 2    5.49058
# 3    3.71153
# 4    2.82053
# 5    6.66103
# 6   18.00021
# 7   12.03577
# 8   13.12868
# 9    9.35334
# 10   5.60596
# 11   1.68257
# 12   2.04781
